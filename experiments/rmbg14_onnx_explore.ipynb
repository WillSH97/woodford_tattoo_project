# %%
from transformers import pipeline
# image_path = "https://farm5.staticflickr.com/4007/4322154488_997e69e4cf_z.jpg"
pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True, accelerator="ort", device='cpu')

# %%
from PIL import Image
testimage = Image.open('testbgremove.png')
testimage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x256>

# %%
pipe(testimage)
# Out:
# <PIL.Image.Image image mode=RGBA size=512x256>
